# %% [markdown]
# # Chapter 5. 지도학습: 회귀 - 배포용

# %% [markdown]
# 지도학습 : 회귀, 분류
#   - 회귀(regression) : input -> continuous value  --> this chapter
#   - 분류(classification) : input -> discrete value (class,label,category)  --> chapter 6

# %% [markdown]
# ## 5.1 1차원 입력 직선 모델

# %% [markdown]
# training data: 나이 $\textbf{x}$와 키 $\textbf{t}$의 column data
# ![대체 텍스트](식5-1.JPG)
# - $x_n$ - 입력변수, $t_n$ - 목표변수(target)
# - $\textbf{x}$ - 입력 데이터, $\textbf{t}$ - 목표 데이터
#
# object - training data에 없는 test data에 대해서 사람의 나이 $\textbf{x}$에 대해 그 사람의 키 $\textbf{t}$를 예측

# %% [markdown]
# training을 위해 입력데이터 $\textbf{x}$와 목표데이터 $\textbf{t}$를 생성

# %%
# 리스트 5-1-(1)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


# 데이터 생성 --------------------------------
np.random.seed(seed=1) # 난수를 고정
X_min = 4 # X의 하한(표시 용)
X_max = 30 # X의 상한(표시 용)
X_n = 16 # X의 상한(표시 용)
X = 5 + 25 * np.random.rand(X_n)
Prm_c = [170, 108, 0.2] # 생성 매개 변수
T = Prm_c[0] - Prm_c[1] * np.exp(-Prm_c[2] * X) + 4 * np.random.randn(X_n) # (A)
np.savez('ch5_data.npz', X=X, X_min=X_min, X_max=X_max, X_n=X_n, T=T) # (B)

# %% [markdown]
# ![대체 텍스트](그림5-1.JPG)

# %% [markdown]
# 생성된 training data - 입력데이터 $\textbf{x}$

# %%
# 리스트 5-1-(2)
print(X)      # 입력 데이터
# Out:
# [15.42555012 23.00811234  5.00285937 12.55831432  8.66889727  7.30846487
#   9.65650528 13.63901818 14.91918686 18.47041835 15.47986286 22.13048751
#  10.11130624 26.95293591  5.68468983 21.76168775]

# %%
# 리스트 5-1-(3)
print(np.round(X, 2))      # 소수 둘째자리까지 반올림
# Out:
# [15.43 23.01  5.   12.56  8.67  7.31  9.66 13.64 14.92 18.47 15.48 22.13
#  10.11 26.95  5.68 21.76]

# %% [markdown]
# 생성된 training data - 목표 데이터 $\textbf{t}$

# %%
# 리스트 5-1-(4)
print(np.round(T, 2))      # 목표 데이터
# Out:
# [170.91 160.68 129.   159.7  155.46 140.56 153.65 159.43 164.7  169.65
#  160.71 173.29 159.31 171.52 138.96 165.87]

# %% [markdown]
# 생성된 training data에 대한 그래프

# %%
# 리스트 5-1-(5)
# 데이터 그래프 ------------------------------
plt.figure(figsize=(4, 4))
plt.plot(X, T, marker='o', linestyle='None',
         markeredgecolor='black', color='cornflowerblue')
plt.xlim(X_min, X_max)
plt.grid(True)
plt.show()

# %% [markdown]
# ### 5.1.1 직선 모델 (linear regression)

# %% [markdown]
# training data를 가장 잘 표현할 수 있는 직선은?
# ![대체 텍스트](그림5-2.JPG)

# %% [markdown]
# 직선의 방정식은?
# ![대체 텍스트](식5-2.JPG)
# $x$는 나이를 나타내고, $y(x)$는 $x$에 대한 $t$의 예측치를 표현한다.
#
# 직선이 training data에 가장 잘 부합할려면 $w_0$와 $w_1$을 어떻게 정할까?

# %% [markdown]
# ### 5.1.2 제곱 오차 함수

# %% [markdown]
# ![대체 텍스트](그림5-3.JPG)

# %% [markdown]
# 평균 제곱 오차 (Mean Square Error, MSE)
# ![대체 텍스트](식5-3.JPG)
# where
# ![대체 텍스트](식5-4.JPG)

# %% [markdown]
# 일단 $\textbf{w}$와 $J$의 관계를 그래프로 표현해 보자.

# %%
# 리스트 5-1-(6)

from mpl_toolkits.mplot3d import Axes3D
# 평균 오차 함수 ------------------------------
def mse_line(x, t, w):
    y = w[0]*x+w[1]            # 여기에 None 대신에 적절한 코드를 입력하시오.
    mse = np.mean((y-t)**2)          # 여기에 None 대신에 적절한 코드를 입력하시오.
    return mse

# 계산 --------------------------------------
wn = 100 # 등고선 표시 해상도
w0_range = [-25, 25]
w1_range = [120, 170]
w0 = np.linspace(w0_range[0], w0_range[1], wn)
w1 = np.linspace(w1_range[0], w1_range[1], wn)
ww0, ww1 = np.meshgrid(w0, w1)      
J = np.zeros((len(w0), len(w1)))    
for i1 in range(wn):            # 중첩 for 문에서 i0,i1의 순서는 상관 없음
    for i0 in range(wn):
        J[i1, i0] = mse_line(X,T,(w0[i0],w1[i1]))        # 여기에 None 대신에 적절한 코드를 입력하시오.

# 표시 --------------------------------------
plt.figure(figsize=(9.5, 4))
plt.subplots_adjust(wspace=0.5)

ax = plt.subplot(1, 2, 1, projection='3d')
ax.plot_surface(ww0, ww1, J, rstride=10, cstride=10, alpha=0.3,
                color='blue', edgecolor='black')
ax.set_xticks([-20, 0, 20])
ax.set_yticks([120, 140, 160])
ax.set_xlabel('$w_0$')
ax.set_ylabel('$w_1$')
ax.view_init(20, -60)

plt.subplot(1, 2, 2)
cont = plt.contour(ww0, ww1, J, 30, colors='black',
                   levels=[100, 1000, 10000, 100000])
cont.clabel(fmt='%1.0f', fontsize=8)
plt.xlabel('$w_0$')
plt.ylabel('$w_1$')
plt.grid(True)
plt.show()

# %% [markdown]
# 위의 그래프에서 $w_0=3,w_1=135$ 근처에서 $J$가 최소값을 가짐

# %% [markdown]
# ### 5.1.3 매개변수 구하기 (gradient descent)

# %% [markdown]
# - 초기 위치로 적당한 $w_0$와 $w_1$을 결정
# - 이 점에서의 기울기를 확인하고 $J$가 감소하는 방향으로 $w_0$와 $w_1$을 조금만 진행
# - 위의 과정을 여러 번 반복하여 최종적으로 $J$가 가장 작아지는 $w_0$와 $w_1$을 수정
# ![그림5-5 기울기(gradient)](그림5-5.JPG)
#
# 기울기(gradient) of $J$
# - $\nabla_W J = \left[ \frac{\partial J}{\partial w_0}, \frac{\partial J}{\partial w_1} \right]^T$
#
# $J$를 최소화하려면 $J$의 기울기의 반대방향 $-\nabla_W J = -\left[ \frac{\partial J}{\partial w_0}, \frac{\partial J}{\partial w_1} \right]^T$으로 진행

# %% [markdown]
# $\textbf{w}$의 갱신방법(학습법칙)을 행렬표기로 나타내면
# ![대체 텍스트](식5-5.JPG)
# where $\alpha$ = 학습율(learning rate)
#
# 위의 수식을 각 성분별로 나타내면
# ![대체 텍스트](식5-7.JPG)

# %% [markdown]
# Gradient를 구하기 위하여 $J$를 편미분 하면
# ![대체 텍스트](식5-8.JPG)
# ![대체 텍스트](식5-9.JPG)
# ![대체 텍스트](식5-10.JPG)
#
# 따라서 (식5-6),(식5-7)의 학습법칙은 아래와 같이 다시 쓸 수 있다.
# ![대체 텍스트](식5-11.JPG)

# %% [markdown]
# 아래는 (식5-9),(식5-10)에 대한 프로그램이다.

# %%
# 리스트 5-1-(7)
# 평균 제곱 오차의 기울기 ------------------------
def dmse_line(x, t, w):
    y = w[0] * x + w[1]
    d_w0 = 2*np.mean((y-t)*x)            # 여기에 None 대신에 적절한 코드를 입력하시오.
    d_w1 = 2*np.mean(y-t)            # 여기에 None 대신에 적절한 코드를 입력하시오.
    return d_w0, d_w1

# %% [markdown]
# 초기값 $\textbf{w = [10, 165]}$에서의 기울기

# %%
# 리스트 5-1-(8)
d_w = dmse_line(X, T, [10, 165])
print(np.round(d_w, 1))
# Out:
# [5046.3  301.8]

# %% [markdown]
# 경사하강법(gradient descent) 구현

# %%
# 리스트 5-1-(9)
# 경사하강법 ------------------------------------
def fit_line_num(x, t):
    w_init = [10.0, 165.0] # 초기 매개 변수
    alpha = 0.001 # 학습률
    i_max = 100000 # 반복의 최대 수
    eps = 0.1 # 반복을 종료 기울기의 절대 값의 한계
    w_i = np.zeros([i_max, 2])    # iteration 별 w=[w0,w1] 값의 변경 내역
    w_i[0, :] = w_init
    for i in range(1, i_max):
        mse = mse_line(x, t, w_i[i - 1])
        if i % 1000 == 0:
            print("Iter =", i, ",    MSE = ", mse)
        dmse = dmse_line(x, t, w_i[i - 1])
        w_i[i, 0] = w_i[i-1,0]-alpha*dmse[0]        # 여기에 None 대신에 적절한 코드를 입력하시오.
        w_i[i, 1] = w_i[i-1,1]-alpha*dmse[1]        # 여기에 None 대신에 적절한 코드를 입력하시오.
        if max(np.absolute(dmse)) < eps: # 종료판정, np.absolute는 절대치
            break
    w0 = w_i[i, 0]
    w1 = w_i[i, 1]
    w_i = w_i[:i, :]
    return w0, w1, dmse, w_i


# 메인 ------------------------------------
plt.figure(figsize=(4, 4)) # MSE의 등고선 표시
wn = 100 # 등고선 해상도
w0_range = [-25, 25]
w1_range = [120, 170]
w0 = np.linspace(w0_range[0], w0_range[1], wn)
w1 = np.linspace(w1_range[0], w1_range[1], wn)
ww0, ww1 = np.meshgrid(w0, w1)
J = np.zeros((len(w0), len(w1)))
for i1 in range(wn):        # 중첩 for 문에서 i0,i1의 순서는 상관 없음
    for i0 in range(wn):
        J[i1, i0] = mse_line(X, T, (w0[i0], w1[i1]))
cont = plt.contour(ww0, ww1, J, 30, colors='black',
                   levels=(100, 1000, 10000, 100000))
cont.clabel(fmt='%1.0f', fontsize=8) 
plt.xlabel('$w_0$')
plt.ylabel('$w_1$')
plt.grid(True)

# 경사하강법 호출
W0, W1, dMSE, W_history = fit_line_num(X, T)

# 결과보기
print('반복 횟수 {0}'.format(W_history.shape[0]))
print('W=[{0:.6f}, {1:.6f}]'.format(W0, W1))
print('dMSE=[{0:.6f}, {1:.6f}]'.format(dMSE[0], dMSE[1]))
print('MSE={0:.6f}'.format(mse_line(X, T, [W0, W1])))
plt.plot(W_history[:, 0], W_history[:, 1], '.-',
         color='gray', markersize=10, markeredgecolor='cornflowerblue')
plt.show()
# Out:
# Iter = 1000 ,    MSE =  118.65792631796117
# Iter = 2000 ,    MSE =  85.10901957999423
# Iter = 3000 ,    MSE =  67.72089007209885
# Iter = 4000 ,    MSE =  58.70876189323366
# Iter = 5000 ,    MSE =  54.037848079564846
# Iter = 6000 ,    MSE =  51.61695088173184
# Iter = 7000 ,    MSE =  50.36221926469264
# Iter = 8000 ,    MSE =  49.711901922755324
# Iter = 9000 ,    MSE =  49.37484765594573
# Iter = 10000 ,    MSE =  49.20015513054549
# Iter = 11000 ,    MSE =  49.10961339458228
# Iter = 12000 ,    MSE =  49.062686338416256
# Iter = 13000 ,    MSE =  49.038364421269826
# 반복 횟수 13820
# W=[1.539947, 136.176160]
# dMSE=[-0.005794, 0.099991]
# MSE=49.027452

# %% [markdown]
# 위의 경사하강법으로 구한 $\textbf{w0}$와 $\textbf{w1}$으로 직선(regression line)을 그려보면

# %%
# 리스트 5-1-(10)
# 선 표시 ----------------------------------
def show_line(w):
    xb = np.linspace(X_min, X_max, 100)
    y = w[0] * xb + w[1]
    plt.plot(xb, y, color=(.5, .5, .5), linewidth=4)


# 메인 ------------------------------------
plt.figure(figsize=(4, 4))
W=np.array([W0, W1])
mse = mse_line(X, T, W)
print("w0={0:.3f}, w1={1:.3f}".format(W0, W1))
print("MSE={0:.3f} cm".format(mse))
print("SD={0:.3f} cm".format(np.sqrt(mse)))
show_line(W) 
plt.plot(X, T, marker='o', linestyle='None',
         color='cornflowerblue', markeredgecolor='black') 
plt.xlim(X_min, X_max)
plt.grid(True)
plt.show()
# Out:
# w0=1.540, w1=136.176
# MSE=49.027 cm
# SD=7.002 cm

# %% [markdown]
# ### 5.1.4 선형 모델 매개변수의 해석해

# %% [markdown]
# 직선모델(linear regression)의 매개변수 $\textbf{w}$ 구하기
# - 수치해 : 경사하강법(gradient descent method)을 이용한 근사값
# - 해석해 : 방정식을 이용한 정확한 값

# %% [markdown]
# 목표 : $J$가 극소화되는 $\textbf{w}$ 찾기
# - 즉, (식5-9),(식5-10)에서 기울기가 0이되는 $\textbf{w}$
# ![대체 텍스트](식5-13.JPG)
#
# 우선 (식5-13)을 먼저 계산하기 위하여, 양변을 2로 나누면
# ![대체 텍스트](식5-15.JPG)
# $\sum$을 각 항에 전개하면
# ![대체 텍스트](식5-16.JPG)
# ![대체 텍스트](식5-17.JPG)
# 평균 기호를 < > 로 표현하면
# ![대체 텍스트](식5-17-1.JPG)
# 위의 수식을 < > 를 이용하여 간략하게 표시하면
# ![대체 텍스트](식5-18.JPG)
# 같은 방법으로 (식5-14)를 정리하면
# ![대체 텍스트](식5-19.JPG)
# (식5-18),(식5-19)를 연립방정식으로 $w_0$와 $w_1$을 구하면
# ![대체 텍스트](식5-19-1.JPG)
# ![대체 텍스트](식5-20.JPG)
# ![대체 텍스트](식5-21.JPG)

# %% [markdown]
# 해석해 구하는 프로그램

# %%
# 리스트 5-1-(11)
# 해석해 ------------------------------------
def fit_line(x, t):
    mx = np.mean(x)
    mt = np.mean(t)
    mtx = np.mean(t * x)
    mxx = np.mean(x * x)
    w0 = (mtx-mx*mt)/(mxx-mx**2)        # 여기에 None 대신에 적절한 코드를 입력하시오.
    w1 = mt-mx*(mtx-mt*mx)/(mxx-mx**2)        # 여기에 None 대신에 적절한 코드를 입력하시오.
    return np.array([w0, w1])

# 메인 ------------------------------------
W = fit_line(X, T)
print("w0={0:.3f}, w1={1:.3f}".format(W[0], W[1]))
mse = mse_line(X, T, W)
print("SD={0:.3f} cm".format(np.sqrt(mse)))
plt.figure(figsize=(4, 4))
show_line(W)
plt.plot(X, T, marker='o', linestyle='None',
         color='cornflowerblue', markeredgecolor='black')
plt.xlim(X_min, X_max)
plt.grid(True)
plt.show()
# Out:
# w0=1.558, w1=135.872
# SD=7.001 cm

# %% [markdown]
# 빠르다!!! 그러나 비선형 모델 같은 경우는 해석해를 못 구하는 경우가 많음!

# %% [markdown]
# ## 5.2 2차원 입력면 모델

# %% [markdown]
# 입력 데이터 : 2차원 $\textbf{x} = (x_0,x_1)$
# - 예, 데이터 = (나이, 몸무게)

# %% [markdown]
# 테스트를 위해 몸무게($x_1$)를 아래와 같이 임의로 생성
# ![대체 텍스트](식5-22.JPG)

# %%
# 리스트 5-1-(12)
# 2차원 데이터 생성 --------------------------
X0 = X    # X0 = 나이
X0_min = 5
X0_max = 30
np.random.seed(seed=1) # 난수를 고정
X1 = 23 * (T / 100)**2 + 2 * np.random.randn(X_n)    # X1 = 몸무게
X1_min = 40
X1_max = 75

# %%
# 리스트 5-1-(13)
print(np.round(X0, 2))
print(np.round(X1, 2))
print(np.round(T, 2))
# Out:
# [15.43 23.01  5.   12.56  8.67  7.31  9.66 13.64 14.92 18.47 15.48 22.13
#  10.11 26.95  5.68 21.76]
# [70.43 58.15 37.22 56.51 57.32 40.84 57.79 56.94 63.03 65.69 62.33 64.95
#  57.73 66.89 46.68 61.08]
# [170.91 160.68 129.   159.7  155.46 140.56 153.65 159.43 164.7  169.65
#  160.71 173.29 159.31 171.52 138.96 165.87]

# %%
# 리스트 5-1-(14)
# 2차원 데이터의 표시 ------------------------
def show_data2(ax, x0, x1, t):
    for i in range(len(x0)):
        ax.plot([x0[i], x0[i]], [x1[i], x1[i]],
                [120, t[i]], color='gray')
        ax.plot(x0, x1, t, 'o',
                color='cornflowerblue', markeredgecolor='black',
                markersize=6, markeredgewidth=0.5)
        ax.view_init(elev=35, azim=-75)


# 메인 ------------------------------------
plt.figure(figsize=(6, 5))
ax = plt.subplot(1,1,1,projection='3d')
ax.set_xlabel('$x_0$')
ax.set_ylabel('$x_1$')
show_data2(ax, X0, X1, T)
plt.show()

# %% [markdown]
# ### 5.2.1 데이터의 표시방법

# %% [markdown]
# 입력 데이터 : 2차원 $\textbf{x} = (x_0,x_1)$
# - 예, 데이터 = (나이, 몸무게)
#
# 데이터 표기 방법: $x_{n,m}$ 또는 $x_{nm}$ (n 번째 데이터의 m 번째 특징)
# - $n$ : 데이터 번호
# - $m$ : 벡터의 요소 (0=나이, 1=몸무게 등) 번호

# %% [markdown]
# (나이,몸무게) 데이터에 대한 입력 데이터와 목표(target) 데이터를 행렬로 표현하면:
#
# $\qquad \textbf{x} = \begin{bmatrix} x_{00} & x_{01} \\ x_{10} & x_{11} \\ \vdots & \vdots \\ x_{N-1,0} & x_{N-1,1} \end{bmatrix}, \qquad   \textbf{t} = \begin{bmatrix} t_{0} \\ t_{1} \\ \vdots \\ t_{N-1} \end{bmatrix}$

# %% [markdown]
# ### 5.2.2 면 모델

# %% [markdown]
# (나이,몸무게) 데이터에 대해서는 직선 모델이 아닌 면(plane) 모델이 되므로 회귀식은 아래와 같이 나타낼 수 있다:
#
# $\qquad y(x_0,x_1) = w_0x_0 + w_1x_1 + w_2$
#
# 행렬식으로 나타내면:
#
# $\qquad \textbf{y} = \textbf{w}^T\textbf{x}
# \qquad \text{where} \qquad \textbf{x} = \begin{bmatrix} x_{0} \\ x_{1} \\ 1 \end{bmatrix},
# \qquad \textbf{w} = \begin{bmatrix} w_{0} \\ w_{1} \\ w_{2} \end{bmatrix}$

# %% [markdown]
# 임의의 $\textbf{w}=[1.5,1,90]$에 대해 면을 한번 그려 보자.

# %%
# 리스트 5-1-(15)
#면의 표시 ----------------------------------
def show_plane(ax, w):
    px0 = np.linspace(X0_min, X0_max, 5)
    px1 = np.linspace(X1_min, X1_max, 5)
    px0, px1 = np.meshgrid(px0, px1)
    y = w[0]*px0+w[1]*px1+w[2]        # 여기에 None 대신에 적절한 코드를 입력하시오.
    ax.plot_surface(px0, px1, y, rstride=1, cstride=1, alpha=0.3,
                    color='blue', edgecolor='black') 

#면의 MSE -----------------------------------
def mse_plane(x0, x1, t, w):
    y = w[0]*x0+w[1]*x1 +w[2]        # 여기에 None 대신에 적절한 코드를 입력하시오.
    mse = np.mean((y-t)**2)       # 여기에 None 대신에 적절한 코드를 입력하시오.
    return mse

# 메인 ------------------------------------
plt.figure(figsize=(6, 5))
ax = plt.subplot(1, 1, 1, projection='3d')
W = [1.5, 1, 90]    # 임의의 W
show_plane(ax, W) 
ax.set_xlabel('$x_0$')
ax.set_ylabel('$x_1$')
show_data2(ax, X0, X1, T)
mse = mse_plane(X0, X1, T, W)
print("SD={0:.3f} cm".format(np.sqrt(mse)))
plt.show()
# Out:
# SD=12.876 cm

# %% [markdown]
# 위의 그래프에서 면(plane)의 함수는
# ![대체 텍스트](식5-28.JPG)

# %% [markdown]
# **면모델에 대한 평균 제곱 오차 (Mean Square Error, MSE)**:
# ![대체 텍스트](식5-3.JPG)
# $\qquad \qquad \qquad \qquad \qquad \qquad$ where
# $\qquad y_n = y(x_{n0},x_{n1}) = w_0x_{n0} + w_1x_{n1} + w_2$

# %% [markdown]
# **면모델에 대해 매개변수 구하기 (경사하강법)**

# %% [markdown]
# 기울기(gradient) of $J$
#
# $\qquad \nabla_W J = \left[ \frac{\partial J}{\partial w_0}, \frac{\partial J}{\partial w_1}, \frac{\partial J}{\partial w_2} \right]^T$

# %% [markdown]
# $\textbf{w}$의 갱신방법(학습법칙)을 행렬표기로 나타내면
# ![대체 텍스트](식5-5.JPG)
# $\qquad$ where $\alpha$ = 학습율(learning rate)

# %% [markdown]
# Gradient를 구하기 위하여 $J$를 편미분 하여 다시 쓰면:
#
# $\qquad w_0(t+1) = w_0(t) - \alpha\frac{2}{N}\sum\limits_{n=0}^{N-1}{(y_n-t_n)x_{n0}}$
#
# $\qquad w_1(t+1) = w_1(t) - \alpha\frac{2}{N}\sum\limits_{n=0}^{N-1}{(y_n-t_n)x_{n1}}$
#
# $\qquad w_2(t+1) = w_2(t) - \alpha\frac{2}{N}\sum\limits_{n=0}^{N-1}{(y_n-t_n)}$

# %% [markdown]
# **실습문제**: 위의 2차원 입력데이터와 면(plane) 모델에 대해 평균제곱오차(mean square error) 함수와 경사하강법(gradient descent)을 이용해 최적의 면(plane) 함수를 구하시오.

# %%
#면의 MSE -----------------------------------
def mse_plane(x0, x1, t, w):
    y=w[0]*x0+w[1]*x1+w[2]
    mse=np.mean((y-t)**2)
    # 여기에 pass 대신에 적절한 코드를 입력하시오. 여러 라인이 될 수 있습니다.
    return mse

# 면의 평균 제곱 오차의 기울기 ------------------------
def dmse_plane(x0, x1, t, w):
    y = w[0]*x0+w[1]*x1+w[2]                 # 여기에 pass 대신에 적절한 코드를 입력하시오. 여러 라인이 될 수 있습니다.
    d_w0 = 2*np.mean((y-t)*x0)
    d_w1 = 2*np.mean((y-t)*x1)
    d_w2 = 2*np.mean(y-t)
    return d_w0, d_w1, d_w2

# %%
print(mse_plane(X0, X1, T, [1, 1, 1]))  
print(mse_plane(X0, X1, T, [1, 2, 3]))    
print(mse_plane(X0, X1, T, [1, 2, 10]))    
print(mse_plane(X0, X1, T, [1.5, 1, 90]))
d_w = dmse_plane(X0, X1, T, [1.5, 1, 90])
print(np.round(d_w, 1))
# Out:
# 7272.569007333825
# 773.7774577343271
# 466.2669541504873
# 165.78895635193032
# [ 396.5 1345.9   22. ]

# %%
# 면의 경사하강법 ------------------------------------
def fit_plane_num(x0, x1, t):
    w_init = [1,2,10]                # 여기에 pass 대신에 적절한 코드를 입력하시오. 여러 라인이 될 수 있습니다.
    alpha = 0.0001
    i_max = 1000000
    eps = 0.1
    w_i = np.zeros([i_max,3])
    w_i[0,:] = w_init
    print("initial MSE = ",np.round(mse_plane(x0,x1,t,w_i[0,:]),3)," W = ",np.round(w_i[0::]))
    for i in range(1,i_max):
        mse = mse_plane(x0,x1,t,w_i[i-1])
        dmse = dmse_plane(x0,x1,t,w_i[i-1])
        w_i[i,0]=w_i[i-1,0]-alpha*dmse[0]
        w_i[i,1]=w_i[i-1,1]-alpha*dmse[1]
        w_i[i,2]=w_i[i-1,2]-alpha*dmse[2]
        if i%10000 == 0:
            print("Iter=",i," MSE =",np.round(mse,3)," W=",np.round(w_i[i],3), " dMSE=",np.round(dmse,3))
        if max(np.absolute(dmse))<eps:
            break
    w0 = w_i[i,0]
    w1 = w_i[i,1]
    w2 = w_i[i,2]
    w_i = w_i[:i,:]
    return w0, w1, w2, dmse, w_i

# %%
# 메인 ------------------------------------

# 경사하강법 호출
W0, W1, W2, dMSE, W_history = fit_plane_num(X0, X1, T)

# 결과보기
print('반복 횟수 {0}'.format(W_history.shape[0]))
print('W=[{0:.6f}, {1:.6f}, {2:.6f}]'.format(W0, W1, W2))
print('dMSE=[{0:.6f}, {1:.6f}, {2:.6f}]'.format(dMSE[0], dMSE[1], dMSE[2]))
print('MSE={0:.6f}'.format(mse_plane(X0, X1, T, [W0, W1, W2])))
# Out:
# Initial MSE =  466.267    W =  [ 1.  2. 10.]
# Iter = 10000    MSE =  107.556    W =  [-0.686  2.671 12.735]    dMSE =  [-0.04   0.055 -2.647]
# Iter = 20000    MSE =  100.781    W =  [-0.647  2.617 15.336]    dMSE =  [-0.038  0.053 -2.557]
# Iter = 30000    MSE =  94.461    W =  [-0.609  2.565 17.85 ]    dMSE =  [-0.037  0.051 -2.47 ]
# Iter = 40000    MSE =  88.564    W =  [-0.573  2.514 20.277]    dMSE =  [-0.036  0.05  -2.386]
# Iter = 50000    MSE =  83.062    W =  [-0.538  2.466 22.622]    dMSE =  [-0.034  0.048 -2.304]
# Iter = 60000    MSE =  77.929    W =  [-0.504  2.419 24.887]    dMSE =  [-0.033  0.046 -2.226]
# Iter = 70000    MSE =  73.14    W =  [-0.471  2.373 27.074]    dMSE =  [-0.032  0.045 -2.15 ]
# Iter = 80000    MSE =  68.672    W =  [-0.44   2.329 29.187]    dMSE =  [-0.031  0.043 -2.077]
# Iter = 90000    MSE =  64.503    W =  [-0.409  2.287 31.228]    dMSE =  [-0.03   0.042 -2.006]
# Iter = 100000    MSE =  60.614    W =  [-0.38   2.246 33.199]    dMSE =  [-0.029  0.04  -1.937]
# Iter = 110000    MSE =  56.986    W =  [-0.351  2.206 35.103]    dMSE =  [-0.028  0.039 -1.871]
# Iter = 120000    MSE =  53.6    W =  [-0.324  2.168 36.943]    dMSE =  [-0.027  0.038 -1.807]
# Iter = 130000    MSE =  50.442    W =  [-0.297  2.131 38.719]    dMSE =  [-0.026  0.036 -1.746]
# Iter = 140000    MSE =  47.495    W =  [-0.271  2.096 40.435]    dMSE =  [-0.025  0.035 -1.686]
# Iter = 150000    MSE =  44.746    W =  [-0.247  2.061 42.092]    dMSE =  [-0.024  0.034 -1.629]
# Iter = 160000    MSE =  42.181    W =  [-0.223  2.028 43.693]    dMSE =  [-0.024  0.033 -1.573]
# Iter = 170000    MSE =  39.788    W =  [-0.199  1.996 45.24 ]    dMSE =  [-0.023  0.032 -1.52 ]
# Iter = 180000    MSE =  37.556    W =  [-0.177  1.965 46.733]    dMSE =  [-0.022  0.03  -1.468]
# Iter = 190000    MSE =  35.473    W =  [-0.156  1.935 48.176]    dMSE =  [-0.021  0.029 -1.418]
# Iter = 200000    MSE =  33.53    W =  [-0.135  1.906 49.57 ]    dMSE =  [-0.02   0.028 -1.369]
# Iter = 210000    MSE =  31.717    W =  [-0.115  1.878 50.916]    dMSE =  [-0.02   0.027 -1.323]
# Iter = 220000    MSE =  30.025    W =  [-0.095  1.851 52.216]    dMSE =  [-0.019  0.027 -1.278]
# Iter = 230000    MSE =  28.447    W =  [-0.076  1.825 53.471]    dMSE =  [-0.018  0.026 -1.234]
# Iter = 240000    MSE =  26.975    W =  [-0.058  1.8   54.684]    dMSE =  [-0.018  0.025 -1.192]
# Iter = 250000    MSE =  25.601    W =  [-4.1000e-02  1.7760e+00  5.5856e+01]    dMSE =  [-0.017  0.024 -1.151]
# Iter = 260000    MSE =  24.319    W =  [-2.4000e-02  1.7520e+00  5.6988e+01]    dMSE =  [-0.017  0.023 -1.112]
# Iter = 270000    MSE =  23.124    W =  [-7.0000e-03  1.7290e+00  5.8081e+01]    dMSE =  [-0.016  0.022 -1.074]
# Iter = 280000    MSE =  22.008    W =  [8.0000e-03 1.7070e+00 5.9136e+01]    dMSE =  [-0.016  0.022 -1.038]
# Iter = 290000    MSE =  20.967    W =  [2.4000e-02 1.6860e+00 6.0156e+01]    dMSE =  [-0.015  0.021 -1.002]
# Iter = 300000    MSE =  19.996    W =  [3.8000e-02 1.6660e+00 6.1141e+01]    dMSE =  [-0.014  0.02  -0.968]
# Iter = 310000    MSE =  19.09    W =  [5.3000e-02 1.6460e+00 6.2093e+01]    dMSE =  [-0.014  0.019 -0.935]
# Iter = 320000    MSE =  18.245    W =  [ 0.066  1.627 63.012]    dMSE =  [-0.014  0.019 -0.903]
# Iter = 330000    MSE =  17.456    W =  [ 0.08   1.609 63.899]    dMSE =  [-0.013  0.018 -0.872]
# Iter = 340000    MSE =  16.721    W =  [ 0.093  1.591 64.757]    dMSE =  [-0.013  0.017 -0.843]
# Iter = 350000    MSE =  16.034    W =  [ 0.105  1.574 65.585]    dMSE =  [-0.012  0.017 -0.814]
# Iter = 360000    MSE =  15.394    W =  [ 0.117  1.557 66.385]    dMSE =  [-0.012  0.016 -0.786]
# Iter = 370000    MSE =  14.796    W =  [ 0.129  1.541 67.158]    dMSE =  [-0.011  0.016 -0.759]
# Iter = 380000    MSE =  14.239    W =  [ 0.14   1.525 67.904]    dMSE =  [-0.011  0.015 -0.733]
# Iter = 390000    MSE =  13.719    W =  [ 0.15   1.51  68.625]    dMSE =  [-0.011  0.015 -0.708]
# Iter = 400000    MSE =  13.234    W =  [ 0.161  1.496 69.321]    dMSE =  [-0.01   0.014 -0.684]
# Iter = 410000    MSE =  12.781    W =  [ 0.171  1.482 69.994]    dMSE =  [-0.01   0.014 -0.661]
# Iter = 420000    MSE =  12.359    W =  [ 0.181  1.469 70.643]    dMSE =  [-0.01   0.013 -0.638]
# Iter = 430000    MSE =  11.965    W =  [ 0.19   1.455 71.271]    dMSE =  [-0.009  0.013 -0.617]
# Iter = 440000    MSE =  11.597    W =  [ 0.199  1.443 71.877]    dMSE =  [-0.009  0.012 -0.596]
# Iter = 450000    MSE =  11.254    W =  [ 0.208  1.431 72.462]    dMSE =  [-0.009  0.012 -0.575]
# Iter = 460000    MSE =  10.934    W =  [ 0.216  1.419 73.028]    dMSE =  [-0.008  0.012 -0.556]
# Iter = 470000    MSE =  10.636    W =  [ 0.225  1.408 73.574]    dMSE =  [-0.008  0.011 -0.537]
# Iter = 480000    MSE =  10.357    W =  [ 0.232  1.397 74.102]    dMSE =  [-0.008  0.011 -0.518]
# Iter = 490000    MSE =  10.097    W =  [ 0.24   1.386 74.611]    dMSE =  [-0.007  0.01  -0.501]
# Iter = 500000    MSE =  9.855    W =  [ 0.247  1.376 75.103]    dMSE =  [-0.007  0.01  -0.484]
# Iter = 510000    MSE =  9.628    W =  [ 0.255  1.366 75.579]    dMSE =  [-0.007  0.01  -0.467]
# Iter = 520000    MSE =  9.417    W =  [ 0.261  1.357 76.038]    dMSE =  [-0.007  0.009 -0.451]
# Iter = 530000    MSE =  9.221    W =  [ 0.268  1.347 76.482]    dMSE =  [-0.007  0.009 -0.436]
# Iter = 540000    MSE =  9.037    W =  [ 0.274  1.338 76.91 ]    dMSE =  [-0.006  0.009 -0.421]
# Iter = 550000    MSE =  8.865    W =  [ 0.281  1.33  77.324]    dMSE =  [-0.006  0.008 -0.407]
# Iter = 560000    MSE =  8.706    W =  [ 0.287  1.322 77.723]    dMSE =  [-0.006  0.008 -0.393]
# Iter = 570000    MSE =  8.556    W =  [ 0.292  1.314 78.11 ]    dMSE =  [-0.006  0.008 -0.379]
# Iter = 580000    MSE =  8.417    W =  [ 0.298  1.306 78.482]    dMSE =  [-0.005  0.008 -0.366]
# Iter = 590000    MSE =  8.287    W =  [ 0.303  1.298 78.843]    dMSE =  [-0.005  0.007 -0.354]
# Iter = 600000    MSE =  8.166    W =  [ 0.309  1.291 79.191]    dMSE =  [-0.005  0.007 -0.342]
# Iter = 610000    MSE =  8.053    W =  [ 0.314  1.284 79.527]    dMSE =  [-0.005  0.007 -0.33 ]
# Iter = 620000    MSE =  7.948    W =  [ 0.318  1.277 79.851]    dMSE =  [-0.005  0.007 -0.319]
# Iter = 630000    MSE =  7.849    W =  [ 0.323  1.271 80.165]    dMSE =  [-0.005  0.006 -0.308]
# Iter = 640000    MSE =  7.758    W =  [ 0.328  1.265 80.468]    dMSE =  [-0.004  0.006 -0.298]
# Iter = 650000    MSE =  7.672    W =  [ 0.332  1.258 80.76 ]    dMSE =  [-0.004  0.006 -0.287]
# Iter = 660000    MSE =  7.592    W =  [ 0.336  1.253 81.043]    dMSE =  [-0.004  0.006 -0.278]
# Iter = 670000    MSE =  7.518    W =  [ 0.34   1.247 81.316]    dMSE =  [-0.004  0.006 -0.268]
# Iter = 680000    MSE =  7.448    W =  [ 0.344  1.241 81.579]    dMSE =  [-0.004  0.005 -0.259]
# Iter = 690000    MSE =  7.383    W =  [ 0.348  1.236 81.834]    dMSE =  [-0.004  0.005 -0.25 ]
# Iter = 700000    MSE =  7.323    W =  [ 0.352  1.231 82.08 ]    dMSE =  [-0.004  0.005 -0.242]
# Iter = 710000    MSE =  7.266    W =  [ 0.355  1.226 82.317]    dMSE =  [-0.003  0.005 -0.233]
# Iter = 720000    MSE =  7.213    W =  [ 0.359  1.221 82.547]    dMSE =  [-0.003  0.005 -0.226]
# Iter = 730000    MSE =  7.164    W =  [ 0.362  1.217 82.769]    dMSE =  [-0.003  0.005 -0.218]
# Iter = 740000    MSE =  7.118    W =  [ 0.365  1.212 82.983]    dMSE =  [-0.003  0.004 -0.21 ]
# Iter = 750000    MSE =  7.076    W =  [ 0.368  1.208 83.189]    dMSE =  [-0.003  0.004 -0.203]
# Iter = 760000    MSE =  7.036    W =  [ 0.371  1.204 83.389]    dMSE =  [-0.003  0.004 -0.196]
# Iter = 770000    MSE =  6.998    W =  [ 0.374  1.2   83.582]    dMSE =  [-0.003  0.004 -0.19 ]
# Iter = 780000    MSE =  6.964    W =  [ 0.377  1.196 83.768]    dMSE =  [-0.003  0.004 -0.183]
# Iter = 790000    MSE =  6.931    W =  [ 0.38   1.192 83.948]    dMSE =  [-0.003  0.004 -0.177]
# Iter = 800000    MSE =  6.901    W =  [ 0.382  1.189 84.122]    dMSE =  [-0.003  0.004 -0.171]
# Iter = 810000    MSE =  6.873    W =  [ 0.385  1.185 84.29 ]    dMSE =  [-0.002  0.003 -0.165]
# Iter = 820000    MSE =  6.846    W =  [ 0.387  1.182 84.452]    dMSE =  [-0.002  0.003 -0.159]
# Iter = 830000    MSE =  6.822    W =  [ 0.39   1.179 84.609]    dMSE =  [-0.002  0.003 -0.154]
# Iter = 840000    MSE =  6.799    W =  [ 0.392  1.175 84.76 ]    dMSE =  [-0.002  0.003 -0.149]
# Iter = 850000    MSE =  6.778    W =  [ 0.394  1.172 84.906]    dMSE =  [-0.002  0.003 -0.144]
# Iter = 860000    MSE =  6.758    W =  [ 0.396  1.169 85.048]    dMSE =  [-0.002  0.003 -0.139]
# Iter = 870000    MSE =  6.739    W =  [ 0.398  1.167 85.184]    dMSE =  [-0.002  0.003 -0.134]
# Iter = 880000    MSE =  6.722    W =  [ 0.4    1.164 85.316]    dMSE =  [-0.002  0.003 -0.129]
# Iter = 890000    MSE =  6.705    W =  [ 0.402  1.161 85.443]    dMSE =  [-0.002  0.003 -0.125]
# Iter = 900000    MSE =  6.69    W =  [ 0.404  1.159 85.566]    dMSE =  [-0.002  0.003 -0.121]
# Iter = 910000    MSE =  6.676    W =  [ 0.406  1.156 85.685]    dMSE =  [-0.002  0.002 -0.117]
# Iter = 920000    MSE =  6.663    W =  [ 0.407  1.154 85.799]    dMSE =  [-0.002  0.002 -0.113]
# Iter = 930000    MSE =  6.651    W =  [ 0.409  1.152 85.91 ]    dMSE =  [-0.002  0.002 -0.109]
# Iter = 940000    MSE =  6.639    W =  [ 0.411  1.149 86.017]    dMSE =  [-0.002  0.002 -0.105]
# Iter = 950000    MSE =  6.629    W =  [ 0.412  1.147 86.12 ]    dMSE =  [-0.002  0.002 -0.102]
# 반복 횟수 954411
# W=[0.412928, 1.146257, 86.164736]
# dMSE=[-0.001496, 0.002076, -0.100000]
# MSE=6.624182

# %%
# 경사하강법으로 구한 W0, W1, W2를 이용해 면(plane)을 다시 그리기
plt.figure(figsize=(12, 5))
ax = plt.subplot(1, 2, 1, projection='3d')
W = [1.5, 1, 90]    # 임의의 W
plt.title("W = [1.5, 1, 90]")
show_plane(ax, W) 
ax.set_xlabel('$x_0$')
ax.set_ylabel('$x_1$')
show_data2(ax, X0, X1, T)
mse = mse_plane(X0, X1, T, W)
print("임의의 W에 대한 SD={0:.3f} cm".format(np.sqrt(mse)))

ax = plt.subplot(1, 2, 2, projection='3d')
W = [W0, W1, W2]    # 경사하강법으로 구한 W
plt.title("W by GD")
show_plane(ax, W) 
ax.set_xlabel('$x_0$')
ax.set_ylabel('$x_1$')
show_data2(ax, X0, X1, T)

mse = mse_plane(X0, X1, T, W)
print("경사하강법에 의한 SD={0:.3f} cm".format(np.sqrt(mse)))

plt.show()
# Out:
# 임의의 W에 대한 SD=12.876 cm
# 경사하강법에 의한 SD=2.574 cm

# %% [markdown]
# ### 5.2.3 매개변수의 해석해 (생략)

# %% [markdown]
# ## 5.3 D차원 선형 회귀 모델

# %% [markdown]
# $x_n$이 $M$ 차원이면
# ![대체 텍스트](식5-24.JPG)
# 모든 데이터에 대해서는
# ![대체 텍스트](식5-25.JPG)
# 차원 $m$에 대해서만 정렬
# ![대체 텍스트](식5-26.JPG)
# Target vector는
# ![대체 텍스트](식5-27.JPG)

# %% [markdown]
# ### 5.3.1 D차원 선형 회귀 모델

# %% [markdown]
# ![대체 텍스트](식5-37.JPG)
#
# 모델을 쉽게 하기 위해 절편 $w_D$를 생략하면
# ![대체 텍스트](식5-38.JPG)
# 위와 같이 항상 원점 $\textbf{x}=[0,0,...,0]$을 지나는 hyperplane이 됨
#
# 행렬 표기법을 사용하여 짧게 정리하면
# ![대체 텍스트](식5-39.JPG)
#
# 원점을 지나지 않는 hyperplane은 항상 $x_D=1$을 추가해서 $\textbf{x}$를 $D+1$차원으로 확장하면
#
# $y(x) = w_0x_0+\cdots+w_{D-1}x_{D-1}+w_Dx_D = [w_0 \cdots w_D] \begin{bmatrix} x_{0} \\ \vdots \\ x_{D} \end{bmatrix} = \textbf{w}^T\textbf{x}$

# %% [markdown]
# ### 5.3.2 매개 변수의 해석해 (이후 모두 생략)
